# %%
import json
with open("sample3.json") as file:
    data=json.load(file)
data
# Out:
# {'someone': 1794271337,
#  'slide': 1917366740.6820364,
#  'dark': 'however',
#  'substance': {'wealth': 1174622014,
#   'needs': 1045740936,
#   'love': False,
#   'place': ['reason',
#    False,
#    'pain',
#    'stove',
#    False,
#    False,
#    'thank',
#    False,
#    1312595752,
#    'identity',
#    'such',
#    'try',
#    'simplest',
#    False,
#    False,
#    -74516630.19845057,
#    'certain',
#    'swimming',
#    2042844988,
#    'grabbed',
#    False,
#    -2078604053.5433674,
#    1373090049,
#    -822409970.4919887,
#    True,
#    -111472615.25488901,
#    -599905162.6849608,
#    'brief',
#    'think',
#    True,
#    True,
#    False,
#    'box',
#    'glad',
#    -947049023],
#   'paper': -961407510,
#   'from': True,
#   'labor': 'is',
#   'saved': True,
#   'electricity': True,
#   'mile': -209140164.16875553,
#   'activity': 'tail',
#   'threw': False,
#   'mathematics': 'dirt',
#   'stay': -1478129794,
#   'concerned': False,
#   'log': 'satisfied',
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
dt=pd.DataFrame(data)
dt.head
# Out:
# <bound method NDFrame.head of                 someone         slide     dark  \
# activity     1794271337  1.917367e+09  however
# arrangement  1794271337  1.917367e+09  however
# camera       1794271337  1.917367e+09  however
# concerned    1794271337  1.917367e+09  however
# dot          1794271337  1.917367e+09  however
# electricity  1794271337  1.917367e+09  however
# from         1794271337  1.917367e+09  however
# hall         1794271337  1.917367e+09  however
# instead      1794271337  1.917367e+09  however
# judge        1794271337  1.917367e+09  however
# labor        1794271337  1.917367e+09  however
# laid         1794271337  1.917367e+09  however
# larger       1794271337  1.917367e+09  however
# log          1794271337  1.917367e+09  however
# love         1794271337  1.917367e+09  however
# mark         1794271337  1.917367e+09  however
# mathematics  1794271337  1.917367e+09  however
# meat         1794271337  1.917367e+09  however
# ...

# %%
dt
# Out:
#                 someone         slide     dark  \
# activity     1794271337  1.917367e+09  however
# arrangement  1794271337  1.917367e+09  however
# camera       1794271337  1.917367e+09  however
# concerned    1794271337  1.917367e+09  however
# dot          1794271337  1.917367e+09  however
# electricity  1794271337  1.917367e+09  however
# from         1794271337  1.917367e+09  however
# hall         1794271337  1.917367e+09  however
# instead      1794271337  1.917367e+09  however
# judge        1794271337  1.917367e+09  however
# labor        1794271337  1.917367e+09  however
# laid         1794271337  1.917367e+09  however
# larger       1794271337  1.917367e+09  however
# log          1794271337  1.917367e+09  however
# love         1794271337  1.917367e+09  however
# mark         1794271337  1.917367e+09  however
# mathematics  1794271337  1.917367e+09  however
# meat         1794271337  1.917367e+09  however
# mile         1794271337  1.917367e+09  however
# ...

# %%
filtered_data = [item for item in dt if isinstance(item, dict) and item.get("age", 0) > 25]
print(filtered_data)
# Out:
# []

# %%
dt.head
# Out:
# <bound method NDFrame.head of                 someone         slide     dark  \
# activity     1794271337  1.917367e+09  however
# arrangement  1794271337  1.917367e+09  however
# camera       1794271337  1.917367e+09  however
# concerned    1794271337  1.917367e+09  however
# dot          1794271337  1.917367e+09  however
# electricity  1794271337  1.917367e+09  however
# from         1794271337  1.917367e+09  however
# hall         1794271337  1.917367e+09  however
# instead      1794271337  1.917367e+09  however
# judge        1794271337  1.917367e+09  however
# labor        1794271337  1.917367e+09  however
# laid         1794271337  1.917367e+09  however
# larger       1794271337  1.917367e+09  however
# log          1794271337  1.917367e+09  however
# love         1794271337  1.917367e+09  however
# mark         1794271337  1.917367e+09  however
# mathematics  1794271337  1.917367e+09  however
# meat         1794271337  1.917367e+09  however
# ...

# %%
dt.dtypes
# Out:
# someone          int64
# slide          float64
# dark            object
# substance       object
# bank              bool
# pressure          bool
# music          float64
# ball            object
# region            bool
# appropriate     object
# post           float64
# pour             int64
# bare            object
# classroom       object
# inside            bool
# seed              bool
# hardly          object
# married           bool
# sport            int64
# replace         object
# height         float64
# hour             int64
# same            object
# potatoes        object
# happily         object
# notice          object
# husband           bool
# anywhere        object
# earn            object
# directly       float64
# friendly       float64
# month             bool
# lot               bool
# end             object
# consonant       object
# dtype: object

# %%
dt.fillna('unknown', inplace=True)

# %%
dt.size
# Out:
# 1225

# %%
dt.shape
# Out:
# (35, 35)

# %%
dt=dt.drop(columns=['husband'])

# %%
dt=dt.drop(columns=['dark'])

# %%
dt
# Out:
#                 someone         slide  \
# activity     1794271337  1.917367e+09
# arrangement  1794271337  1.917367e+09
# camera       1794271337  1.917367e+09
# concerned    1794271337  1.917367e+09
# dot          1794271337  1.917367e+09
# electricity  1794271337  1.917367e+09
# from         1794271337  1.917367e+09
# hall         1794271337  1.917367e+09
# instead      1794271337  1.917367e+09
# judge        1794271337  1.917367e+09
# labor        1794271337  1.917367e+09
# laid         1794271337  1.917367e+09
# larger       1794271337  1.917367e+09
# log          1794271337  1.917367e+09
# love         1794271337  1.917367e+09
# mark         1794271337  1.917367e+09
# mathematics  1794271337  1.917367e+09
# meat         1794271337  1.917367e+09
# mile         1794271337  1.917367e+09
# needs        1794271337  1.917367e+09
# offer        1794271337  1.917367e+09
# paper        1794271337  1.917367e+09
# perfect      1794271337  1.917367e+09
# ...
